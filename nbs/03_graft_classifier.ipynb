# %% [markdown]
# # Greffer un classifieur
#
# > Écris ici la logique permettant à un développeur de fournir son classifieur et de le brancher au modèle AAE.

# %%
#| default_exp graft_classifier

# %% [markdown]
# Dans ton modèle AAE, la tête de classification est `linear`. Une première version simple peut donc remplacer `model.linear` par un module PyTorch donné par l'utilisateur.

# %%
#| export
# TODO: écrire ici les fonctions de greffe du classifieur
