# %% [markdown]
# # Graft a Classifier
#
# > Add the logic that lets a developer provide a classifier and connect it to the AAE model.

# %%
#| default_exp graft_classifier

# %% [markdown]
# In the AAE model, the classification head is `linear`. A first simple version can therefore replace `model.linear` with a PyTorch module provided by the user.

# %%
#| export
# TODO: write the classifier grafting functions here
