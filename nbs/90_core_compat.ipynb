# %% [markdown]
# # Compatibilité core
#
# > Façade de compatibilité pour les anciens imports `tell_me_why.core`.

# %%
#| default_exp core

# %%
#| export
"""Backward-compatible imports for the old `tell_me_why.core` module."""

from tell_me_why.adapters import AAEAdapter, GraftedAAEClassifier, freeze_module
from tell_me_why.config import LatentBatch
from tell_me_why.latent import collect_latents, default_input_getter, default_target_getter

__all__ = [
    "AAEAdapter",
    "GraftedAAEClassifier",
    "LatentBatch",
    "collect_latents",
    "default_input_getter",
    "default_target_getter",
    "freeze_module",
]
