# %% [markdown]
# # Tutoriel
#
# > Ce notebook sert à montrer comment utiliser la librairie. Il ne doit pas forcément exporter du code.

# %% [markdown]
# Quand les notebooks précédents seront remplis, tu pourras montrer ici un exemple complet:
#
# 1. charger les données avec fastai,
# 2. créer le modèle AAE,
# 3. brancher un classifieur,
# 4. extraire l'espace latent,
# 5. afficher les figures.
