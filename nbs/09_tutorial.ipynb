# %% [markdown]
# # Tutoriel rapide
#
# Ce notebook montre l’usage public de la librairie après export des modules nbdev.
#
# Structure inspirée de FasterAI: petits modules par responsabilité, puis API ré-exportée dans `tell_me_why`.

# %%
from torch import nn
from tell_me_why import HumanCenteredAAEConfig, make_grafted_learner

# %%
config = HumanCenteredAAEConfig(encoding_dims=128, classes=2)
classifier = nn.Sequential(
    nn.Linear(config.encoding_dims, 64),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(64, config.classes),
)

# learn = make_grafted_learner(dls, classifier, config=config)
