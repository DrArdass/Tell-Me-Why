# %% [markdown]
# # Tell Me Why
#
# > Greffer un classifieur fastai/PyTorch sur `Human-Centered-xAI/modelAAE_DROPOUT.py` et inspecter son espace latent.

# %% [markdown]
# Ce dépôt est configuré pour nbdev. Le code Python public vit dans `tell_me_why/` et les notebooks `nbs/` documentent l'usage attendu autour du modèle fastai `modelAAE_DROPOUT.py`.
#
# Installation développeur:
#
# ```bash
# python -m pip install -e ".[dev]"
# ```
