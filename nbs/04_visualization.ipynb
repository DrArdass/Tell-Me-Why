# %% [markdown]
# # Visualizations
#
# > Add the functions that display the Gaussian latent space and feature figures.

# %%
#| default_exp visualization

# %% [markdown]
# Start simple: a function that displays `z[:, 0]` vs `z[:, 1]`, then add the feature figures once the computations are ready.

# %%
#| export
# TODO: write the visualization functions to export here
