# %% [markdown]
# # Visualisations
#
# > Écris ici les fonctions pour afficher l'espace latent gaussien et les figures de features.

# %%
#| default_exp visualization

# %% [markdown]
# Commence simple: une fonction pour afficher `z[:, 0]` vs `z[:, 1]`, puis ajoute les figures de features quand les calculs sont prêts.

# %%
#| export
# TODO: écrire ici les fonctions de visualisation à exporter
